# %% [markdown]
# ### **GITHUB LINK** : https://github.com/Aman-ali76/BSAI-1C/tree/main/AMAN%20BSAI%201C

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                 37.0                      4.9
# 1      B379     BANGRES18DEL02                 34.0                      4.5
# 2      5D6D     BANGRES19DEL01                 23.0                      4.4
# 3      7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4      70A2     CHENRES12DEL01                 32.0                      4.6
# ...     ...                ...                  ...                      ...
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
# ...

# %%
df.shape
# Out:
# (10001, 18)

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Type_of_order', 'Type_of_vehicle',
#        'temperature', 'humidity', 'precipitation', 'weather_description',
#        'Unnamed: 14', 'Traffic_Level', 'Distance (km)', 'TARGET'],
#       dtype='object')

# %%
df.rename(columns={'Type_of_order': 'Order_type', 'Type_of_vehicle': 'Vehicle_type', 'temperature': 'Temperature', 'humidity': 'Humidity', 'weather_description': 'Weather','Traffic_Level': 'Traffic','TARGET':'Target'}, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_type', 'Vehicle_type',
#        'Temperature', 'Humidity', 'precipitation', 'Weather', 'Unnamed: 14',
#        'Traffic', 'Distance (km)', 'Target'],
#       dtype='object')

# %%
df.head(8)
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                 37.0                      4.9
# 1  B379     BANGRES18DEL02                 34.0                      4.5
# 2  5D6D     BANGRES19DEL01                 23.0                      4.4
# 3  7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4  70A2     CHENRES12DEL01                 32.0                      4.6
# 5  9BB4      HYDRES09DEL03                 22.0                      4.8
# 6  95B4   RANCHIRES15DEL01                 33.0                      4.7
# 7  9EB2      MYSRES15DEL02                 35.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# ...

# %%
df.tail(3)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 9998             26.913987             75.752891                   27.053987
# 9999             18.994237             72.825553                   19.084237
# 10000                  NaN                   NaN                         NaN
#
#        Delivery_location_longitude Order_type Vehicle_type  Temperature  \
# 9998                     75.892891    Buffet      scooter         23.72
# 9999                     72.915553      Meal      scooter         28.01
# 10000                          NaN        NaN          NaN          NaN
#
# ...

# %%
df.sample(5)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 7617  28F9      JAPRES13DEL02                 21.0                      4.5
# 392   CDB6     AURGRES03DEL01                 26.0                      4.6
# 2441  89B9      HYDRES12DEL02                 23.0                      4.6
# 1937  13CA      VADRES03DEL02                 36.0                      4.7
# 7795  7F17      SURRES12DEL02                 26.0                      4.6
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 7617            26.846156             75.802300                   26.926156
# 392             19.874733             75.353942                   19.984733
# 2441            17.429585             78.392621                   17.559585
# 1937            22.320000             73.170000                   22.340000
# 7795            21.183434             72.814492                   21.263434
#
# ...

# %%
df.drop_duplicates()
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                 37.0                      4.9
# 1      B379     BANGRES18DEL02                 34.0                      4.5
# 2      5D6D     BANGRES19DEL01                 23.0                      4.4
# 3      7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4      70A2     CHENRES12DEL01                 32.0                      4.6
# ...     ...                ...                  ...                      ...
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
# ...

# %%
df.drop(10000,inplace=True)

# %%
df.tail(3)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 9997  8336      HYDRES20DEL01                 36.0                      4.7
# 9998  338B      JAPRES18DEL03                 37.0                      4.6
# 9999  3FB2      MUMRES11DEL03                 29.0                      4.7
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 9997            17.483216             78.552111                   17.493216
# 9998            26.913987             75.752891                   27.053987
# 9999            18.994237             72.825553                   19.084237
#
#       Delivery_location_longitude Order_type Vehicle_type  Temperature  \
# 9997                    78.562111      Meal   motorcycle         22.94
# 9998                    75.892891    Buffet      scooter         23.72
# 9999                    72.915553      Meal      scooter         28.01
#
# ...

# %%
df.drop(columns=['precipitation','Unnamed: 14'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Order_type                   10000 non-null  object
#  9   Vehicle_type                 10000 non-null  object
#  10  Temperature                  9995 non-null   float64
#  11  Humidity                     9995 non-null   float64
# ...

# %%
df[2:99]
# Out:
#           ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 2       5D6D     BANGRES19DEL01                 23.0                      4.4
# 3       7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4       70A2     CHENRES12DEL01                 32.0                      4.6
# 5       9BB4      HYDRES09DEL03                 22.0                      4.8
# 6       95B4   RANCHIRES15DEL01                 33.0                      4.7
# ..       ...                ...                  ...                      ...
# 94  3.50E+07      JAPRES15DEL03                 36.0                      4.8
# 95      B437      SURRES16DEL01                 25.0                      5.0
# 96  9.70E+04      MYSRES16DEL02                 29.0                      5.0
# 97      A3E0      MUMRES05DEL03                 36.0                      4.7
# 98      4161    COIMBRES19DEL02                 33.0                      4.7
#
# ...

# %%
df.loc[2:99,'Vehicle_type']
# Out:
# 2           motorcycle
# 3           motorcycle
# 4              scooter
# 5           motorcycle
# 6              scooter
#             ...
# 95          motorcycle
# 96          motorcycle
# 97    electric_scooter
# 98          motorcycle
# 99             scooter
# Name: Vehicle_type, Length: 98, dtype: object

# %%
df.iloc[2:88,2:5]
# Out:
#     Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 2                  23.0                      4.4            12.914264
# 3                  38.0                      4.7            11.003669
# 4                  32.0                      4.6            12.972793
# 5                  22.0                      4.8            17.431668
# 6                  33.0                      4.7            23.369746
# ..                  ...                      ...                  ...
# 83                 25.0                      4.7            19.254567
# 84                 30.0                      5.0            26.913483
# 85                 24.0                      4.6            17.411028
# 86                 39.0                      4.8            18.516216
# 87                 25.0                      4.8            15.569600
#
# [86 rows x 3 columns]

# %%
df[df["Traffic"].isnull()]
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 33    2876   RANCHIRES02DEL01                 32.0                      3.5
# 52    C1FF     AURGRES20DEL03                 25.0                      5.0
# 57    8E6C      VADRES02DEL02                 39.0                      4.2
# 59    395B      VADRES04DEL03                 36.0                      4.7
# 67    98AA      VADRES16DEL02                 23.0                      4.8
# ...    ...                ...                  ...                      ...
# 9919  D4DC      ALHRES04DEL02                 24.0                      4.7
# 9921  C032      KOLRES08DEL01                 28.0                      4.7
# 9960  D1F1     AURGRES20DEL01                 21.0                      4.9
# 9977  C5A8      BHPRES14DEL02                 24.0                      4.8
# 9988  C7C4      KNPRES08DEL01                 22.0                      4.3
#
# ...

# %%
df[df['Target'] == "#VALUE!"]
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 33    2876   RANCHIRES02DEL01                 32.0                      3.5
# 57    8E6C      VADRES02DEL02                 39.0                      4.2
# 59    395B      VADRES04DEL03                 36.0                      4.7
# 68    273A      VADRES09DEL01                 35.0                      4.8
# 69    A258     CHENRES12DEL03                 39.0                      4.6
# ...    ...                ...                  ...                      ...
# 9535   3EF   RANCHIRES13DEL01                 50.0                      6.0
# 9658  C0B5     AURGRES17DEL02                 26.0                      4.8
# 9758  C0AD     KOLRES010DEL03                 20.0                      4.6
# 9869  C0E8     LUDHRES20DEL03                 29.0                      4.7
# 9921  C032      KOLRES08DEL01                 28.0                      4.7
#
# ...

# %%
df['Target'] = df['Target'].replace('#VALUE!', '0')

# %%
df['Target'] = pd.to_numeric(df['Target'])

# %%
for i in df.index:
    if df.loc[i,'Target'] == 0:
        df.loc[i , 'Target'] = df['Target'].mean()

# %%
df[df['Target'] == "0"]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_type, Vehicle_type, Temperature, Humidity, Weather, Traffic, Distance (km), Target]
# Index: []

# %%
df[df['Delivery_person_Ratings'] < 2]
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 2387  564      JAPRES15DEL03                 15.0                      1.0
# 2905  CD0    INDORES010DEL03                 15.0                      1.0
# 2951  91A      SURRES17DEL03                 15.0                      1.0
# 5902  474     CHENRES15DEL03                 15.0                      1.0
# 9156  73F     BANGRES05DEL01                 15.0                      1.0
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 2387           -26.891191             75.802083                   26.981191
# 2905            22.750040             75.902847                   22.810040
# 2951            21.149569             72.772697                   21.209569
# 5902            13.026286             80.275235                   13.056286
# 9156            12.970324             77.645748                   13.080324
#
# ...

# %%
for i in df.index:
    if df.loc[i,'Delivery_person_Ratings'] < 2:
        df.drop(i,inplace=True)

# %%
df[df['Delivery_person_Ratings'] < 2]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_type, Vehicle_type, Temperature, Humidity, Weather, Traffic, Distance (km), Target]
# Index: []

# %%
x = df['Temperature'].mean()

df['Temperature'] = df['Temperature'].fillna(x)

# %%
df.isnull().sum()
# Out:
# ID                               0
# Delivery_person_ID               0
# Delivery_person_Age              0
# Delivery_person_Ratings          0
# Restaurant_latitude              0
# Restaurant_longitude             0
# Delivery_location_latitude       0
# Delivery_location_longitude      0
# Order_type                       0
# Vehicle_type                     0
# Temperature                      0
# Humidity                         5
# Weather                          5
# Traffic                        914
# Distance (km)                  919
# Target                         541
# dtype: int64

# %%
target  = df['Target'].mode()[0]

df['Target'] = df['Target'].fillna(target)

df['Target']
# Out:
# 0       21.666667
# 1       85.266667
# 2       28.583333
# 3       35.183333
# 4       43.450000
#           ...
# 9995    18.200000
# 9996    32.616667
# 9997    12.016667
# 9998    51.066667
# 9999    43.800000
# Name: Target, Length: 9995, dtype: float64

# %%
df['Weather'] = df['Weather'].fillna(df['Weather'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID                               0
# Delivery_person_ID               0
# Delivery_person_Age              0
# Delivery_person_Ratings          0
# Restaurant_latitude              0
# Restaurant_longitude             0
# Delivery_location_latitude       0
# Delivery_location_longitude      0
# Order_type                       0
# Vehicle_type                     0
# Temperature                      0
# Humidity                         5
# Weather                          0
# Traffic                        914
# Distance (km)                  919
# Target                           0
# dtype: int64

# %%
humidity = df['Humidity'].mean()

df['Humidity'] = df['Humidity'].fillna(humidity)

# %%
df['Distance (km)'] = df['Distance (km)'].fillna(df['Distance (km)'].median())

# %%
df.isnull().sum()
# Out:
# ID                               0
# Delivery_person_ID               0
# Delivery_person_Age              0
# Delivery_person_Ratings          0
# Restaurant_latitude              0
# Restaurant_longitude             0
# Delivery_location_latitude       0
# Delivery_location_longitude      0
# Order_type                       0
# Vehicle_type                     0
# Temperature                      0
# Humidity                         0
# Weather                          0
# Traffic                        914
# Distance (km)                    0
# Target                           0
# dtype: int64

# %%
df['Traffic']
# Out:
# 0             Low
# 1       Very High
# 2             Low
# 3        Moderate
# 4            High
#           ...
# 9995          Low
# 9996         High
# 9997          Low
# 9998    Very High
# 9999         High
# Name: Traffic, Length: 9995, dtype: object

# %%
df['Traffic'] = df['Traffic'].fillna(df['Traffic'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_type                     0
# Vehicle_type                   0
# Temperature                    0
# Humidity                       0
# Weather                        0
# Traffic                        0
# Distance (km)                  0
# Target                         0
# dtype: int64

# %%
df[(df['Restaurant_latitude'] == 0) | (df['Restaurant_longitude'] == 0) ]
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 33    2876   RANCHIRES02DEL01                 32.0                      3.5
# 52    C1FF     AURGRES20DEL03                 25.0                      5.0
# 57    8E6C      VADRES02DEL02                 39.0                      4.2
# 59    395B      VADRES04DEL03                 36.0                      4.7
# 67    98AA      VADRES16DEL02                 23.0                      4.8
# ...    ...                ...                  ...                      ...
# 9914  9359      VADRES07DEL03                 32.0                      4.7
# 9919  D4DC      ALHRES04DEL02                 24.0                      4.7
# 9960  D1F1     AURGRES20DEL01                 21.0                      4.9
# 9977  C5A8      BHPRES14DEL02                 24.0                      4.8
# 9988  C7C4      KNPRES08DEL01                 22.0                      4.3
#
# ...

# %%
rl = df['Restaurant_latitude'].mode()[0]
rlong = df['Restaurant_longitude'].mode()[0]

# %%
for i in df.index:
    if df.loc[i,'Restaurant_latitude'] == 0:
        df.loc[i , 'Restaurant_latitude'] = rl
    if df.loc[i,'Restaurant_longitude'] == 0:
        df.loc[i , 'Restaurant_longitude'] = rlong

# %%
df[(df['Restaurant_latitude'] == 0) |(df['Restaurant_longitude'] == 0) ]
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 33    2876   RANCHIRES02DEL01                 32.0                      3.5
# 52    C1FF     AURGRES20DEL03                 25.0                      5.0
# 57    8E6C      VADRES02DEL02                 39.0                      4.2
# 59    395B      VADRES04DEL03                 36.0                      4.7
# 67    98AA      VADRES16DEL02                 23.0                      4.8
# ...    ...                ...                  ...                      ...
# 9914  9359      VADRES07DEL03                 32.0                      4.7
# 9919  D4DC      ALHRES04DEL02                 24.0                      4.7
# 9960  D1F1     AURGRES20DEL01                 21.0                      4.9
# 9977  C5A8      BHPRES14DEL02                 24.0                      4.8
# 9988  C7C4      KNPRES08DEL01                 22.0                      4.3
#
# ...

# %%
df['new_column'] = 0

df
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0     4607     INDORES13DEL02                 37.0                      4.9
# 1     B379     BANGRES18DEL02                 34.0                      4.5
# 2     5D6D     BANGRES19DEL01                 23.0                      4.4
# 3     7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4     70A2     CHENRES12DEL01                 32.0                      4.6
# ...    ...                ...                  ...                      ...
# 9995  4347      MUMRES07DEL01                 25.0                      4.0
# 9996  11B4      VADRES13DEL03                 32.0                      4.2
# 9997  8336      HYDRES20DEL01                 36.0                      4.7
# 9998  338B      JAPRES18DEL03                 37.0                      4.6
# 9999  3FB2      MUMRES11DEL03                 29.0                      4.7
#
# ...

# %%
df.drop(columns=['new_column'],inplace=True)

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count          9995.000000              9995.000000          9995.000000
# mean             29.529265                 4.631186            16.897566
# std               5.692509                 0.312649             8.321015
# min              20.000000                 2.500000           -30.902872
# 25%              25.000000                 4.500000            12.913041
# 50%              29.000000                 4.700000            18.546258
# 75%              34.000000                 4.800000            22.727021
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count           9995.000000                 9995.000000
# mean              70.174596                   17.411647
# std               23.208662                    7.337502
# min              -88.352885                    0.010000
# ...

# %%
a = df.describe(include='all')

a
# Out:
#               ID Delivery_person_ID  Delivery_person_Age  \
# count       9995               9995          9995.000000
# unique      9990               1285                  NaN
# top     6.00E+02      SURRES16DEL01                  NaN
# freq           2                 22                  NaN
# mean         NaN                NaN            29.529265
# std          NaN                NaN             5.692509
# min          NaN                NaN            20.000000
# 25%          NaN                NaN            25.000000
# 50%          NaN                NaN            29.000000
# 75%          NaN                NaN            34.000000
# max          NaN                NaN            50.000000
#
#         Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# count               9995.000000          9995.000000           9995.000000
# unique                      NaN                  NaN                   NaN
# ...

# %%
a.loc[['top','unique','mean']]
# Out:
#               ID Delivery_person_ID  Delivery_person_Age  \
# top     6.00E+02      SURRES16DEL01                  NaN
# unique      9990               1285                  NaN
# mean         NaN                NaN            29.529265
#
#         Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# top                         NaN                  NaN                   NaN
# unique                      NaN                  NaN                   NaN
# mean                   4.631186            16.897566             70.174596
#
#         Delivery_location_latitude  Delivery_location_longitude Order_type  \
# top                            NaN                          NaN     Snack
# unique                         NaN                          NaN          4
# mean                     17.411647                    70.877236        NaN
#
#        Vehicle_type  Temperature   Humidity    Weather Traffic  Distance (km)  \
# ...

# %%
df['Order_type'].value_counts()
# Out:
# Order_type
# Snack      2550
# Meal       2529
# Drinks     2506
# Buffet     2410
# Name: count, dtype: int64

# %%
df['Vehicle_type'].value_counts()
# Out:
# Vehicle_type
# motorcycle           5860
# scooter              3303
# electric_scooter      814
# bicycle                18
# Name: count, dtype: int64

# %%
df.groupby('Order_type').describe()
# Out:
#            Delivery_person_Age                                               \
#                          count       mean       std   min   25%   50%   75%
# Order_type
# Buffet                  2410.0  29.602490  5.672140  20.0  25.0  29.0  35.0
# Drinks                  2506.0  29.577414  5.714899  20.0  25.0  29.0  34.0
# Meal                    2529.0  29.500593  5.708998  20.0  25.0  29.0  34.0
# Snack                   2550.0  29.441176  5.675226  20.0  25.0  29.0  34.0
#
#                  Delivery_person_Ratings            ... Distance (km)         \
#              max                   count      mean  ...           75%    max
# Order_type                                          ...
# Buffet      50.0                  2410.0  4.633195  ...        18.250  59.67
# Drinks      50.0                  2506.0  4.630926  ...        19.075  59.84
# Meal        50.0                  2529.0  4.620957  ...        19.020  54.46
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
pd.reset_option('display.max_rows')

# %%
df['Delivery_person_Ratings'].value_counts().plot(kind='bar',title="Bar Chart",color='blue')
# Out:
# <Axes: title={'center': 'Bar Chart'}, xlabel='Delivery_person_Ratings'>

# %%
df['Vehicle_type'].value_counts().plot(kind='pie',title="Pie Chart")
# Out:
# <Axes: title={'center': 'Pie Chart'}, ylabel='count'>

# %%
df['Order_type'].value_counts().plot(kind='line',title="Line Chart",color='green')
# Out:
# <Axes: title={'center': 'Line Chart'}, xlabel='Order_type'>

# %%
df.plot(kind='scatter',x='Temperature',y='Humidity',title="Scatter Plot",color='rebeccapurple')
# Out:
# <Axes: title={'center': 'Scatter Plot'}, xlabel='Temperature', ylabel='Humidity'>

# %%
df['Distance (km)'].plot(kind='hist',title="Histogram",color='orange')
# Out:
# <Axes: title={'center': 'Histogram'}, ylabel='Frequency'>

# %%
df['Delivery_person_Age'].value_counts().plot(kind='area',title="Area Chart",color='brown')
# Out:
# <Axes: title={'center': 'Area Chart'}, xlabel='Delivery_person_Age'>

# %%
df.to_csv('data2.csv')
